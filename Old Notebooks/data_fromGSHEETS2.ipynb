# %%
import numpy as np
import pandas as pd

# %%
from datetime import date

today = date.today() # date object
# Format
date_formatted = today.strftime("%m-%d-%Y")

# %%
df = pd.read_csv('https://raw.githubusercontent.com/gigerbytes/ncov-ph-data/master/data/cases_ph.csv')
df.head()
# Out:
#   case_no  age     sex nationality travel_hist detailed_history status  \
# 0  PH3246   15  Female    Filipino                          NaN
# 1  PH3245   67    Male    Filipino                          NaN
# 2  PH3244   48    Male    Filipino                          NaN
# 3  PH3243   24  Female    Filipino                          NaN
# 4  PH3242   65  Female    Filipino                          NaN
#
#   symptoms date_symptoms date_admission   date_lab_confirmed        facility  \
# 0                    NaN            NaN  2020-04-03 00:00:00  For validation
# 1                    NaN            NaN  2020-04-03 00:00:00  For validation
# 2                    NaN            NaN  2020-04-03 00:00:00  For validation
# 3                    NaN            NaN  2020-04-03 00:00:00  For validation
# 4                    NaN            NaN  2020-04-03 00:00:00  For validation
#
#     latitude   longitude       residence dashboard_last_updated  \
# ...

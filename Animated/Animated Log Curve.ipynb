# %%
# %matplotlib notebook

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
# Timestamp
from datetime import date

today = date.today() # date object
# Format
time_stamp = today.strftime("%m-%d-%Y")

# %% [markdown]
# # Loading the csv file from https://ourworldindata.org/

# %%
df = pd.read_csv('covid-confirmed-cases-since-100th-case.csv', parse_dates=True, names=['Entity', 'Code', 'Date', 'Cases', 'Number of days since the 100th confirmed case (days)'])[1:]
df.head()
# Out:
#         Entity Code          Date Cases  \
# 1  Afghanistan  AFG  Dec 31, 2019     0
# 2  Afghanistan  AFG   Jan 1, 2020     0
# 3  Afghanistan  AFG   Jan 2, 2020     0
# 4  Afghanistan  AFG   Jan 3, 2020     0
# 5  Afghanistan  AFG   Jan 4, 2020     0
#
#   Number of days since the 100th confirmed case (days)
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN

# %%
cases = np.array(df.Cases)

for i, x in enumerate(cases):
    if pd.isna(x):
        pass
    else:
        cases[i] = int(x)
        
df.Cases = cases

# %%
df_PH = df[(df.Entity=='Philippines') & (df.Cases >= 1)][['Date', 'Cases']].copy()
df_PH.tail()
# with pd.option_context('display.max_rows', None, 'display.max_columns', None): 
#     display(df_PH)
# Out:
#              Date Cases
# 7661  Apr 2, 2020  2311
# 7662  Apr 3, 2020  2633
# 7663  Apr 4, 2020  3018
# 7664  Apr 5, 2020  3094
# 7665  Apr 6, 2020  3246

# %%
# Best responders

df_Vietnam = df[(df.Entity=='Vietnam') & (df.Cases >= 1)][['Date', 'Cases']].copy()
df_Taiwan = df[(df.Entity=='Taiwan') & (df.Cases >= 1)][['Date', 'Cases']].copy()
df_SoKor = df[(df.Entity=='South Korea') & (df.Cases >= 1)][['Date', 'Cases']].copy()
df_Germany = df[(df.Entity=='Spain') & (df.Cases >= 1)][['Date', 'Cases']].copy()

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None): 
    display(df_Germany)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None): 
    display(df_SoKor)
# Out:
#               Date  Cases
# 8655  Jan 20, 2020      1
# 8656  Jan 21, 2020      1
# 8657  Jan 22, 2020      1
# 8658  Jan 23, 2020      1
# 8659  Jan 24, 2020      2
# 8660  Jan 25, 2020      2
# 8661  Jan 26, 2020      3
# 8662  Jan 27, 2020      4
# 8663  Jan 28, 2020      4
# 8664  Jan 29, 2020      4
# 8665  Jan 30, 2020      4
# 8666  Jan 31, 2020      7
# 8667   Feb 1, 2020     12
# 8668   Feb 2, 2020     15
# 8669   Feb 3, 2020     15
# 8670   Feb 4, 2020     16
# 8671   Feb 5, 2020     18
# 8672   Feb 6, 2020     23
# 8673   Feb 7, 2020     24
# 8674   Feb 8, 2020     24
# 8675   Feb 9, 2020     25
# 8676  Feb 10, 2020     27
# 8677  Feb 11, 2020     28
# 8678  Feb 12, 2020     28
# 8679  Feb 13, 2020     28
# 8680  Feb 14, 2020     28
# 8681  Feb 15, 2020     28
# 8682  Feb 16, 2020     29
# 8683  Feb 17, 2020     30
# 8684  Feb 18, 2020     31
# 8685  Feb 19, 2020     46
# 8686  Feb 20, 2020     80
# 8687  Feb 21, 2020    155
# 8688  Feb 22, 2020    345
# 8689  Feb 23, 2020    601
# 8690  Feb 24, 2020    762
# 8691  Feb 25, 2020    892
# 8692  Feb 26, 2020   1146
# 8693  Feb 27, 2020   1595
# 8694  Feb 28, 2020   2022
# 8695  Feb 29, 2020   2931
# 8696   Mar 1, 2020   3526
# 8697   Mar 2, 2020   4212
# 8698   Mar 3, 2020   4812
# 8699   Mar 4, 2020   5328
# 8700   Mar 5, 2020   5766
# 8701   Mar 6, 2020   6284
# 8702   Mar 7, 2020   6767
# 8703   Mar 8, 2020   7134
# 8704   Mar 9, 2020   7382
# 8705  Mar 10, 2020   7513
# 8706  Mar 11, 2020   7755
# 8707  Mar 12, 2020   7869
# 8708  Mar 13, 2020   7979
# 8709  Mar 14, 2020   8086
# 8710  Mar 15, 2020   8162
# 8711  Mar 16, 2020   8236
# 8712  Mar 17, 2020   8320
# 8713  Mar 18, 2020   8413
# 8714  Mar 19, 2020   8565
# 8715  Mar 20, 2020   8652
# 8716  Mar 21, 2020   8799
# 8717  Mar 22, 2020   8897
# 8718  Mar 23, 2020   8961
# 8719  Mar 24, 2020   9037
# 8720  Mar 25, 2020   9137
# 8721  Mar 26, 2020   9241
# 8722  Mar 27, 2020   9332
# 8723  Mar 28, 2020   9478
# 8724  Mar 29, 2020   9583
# 8725  Mar 30, 2020   9661
# 8726  Mar 31, 2020   9786
# 8727   Apr 1, 2020   9786
# 8728   Apr 2, 2020   9976
# 8729   Apr 3, 2020  10062
# 8730   Apr 4, 2020  10156
# 8731   Apr 5, 2020  10237
# 8732   Apr 6, 2020  10284

# %%
# Worst cases
df_China = df[(df.Entity=='China') & (df.Cases >= 1)][['Date', 'Cases']].copy()
df_USA = df[(df.Entity=='United States') & (df.Cases >= 1)][['Date', 'Cases']].copy()


# Europe
df_Spain = df[(df.Entity=='Spain') & (df.Cases >= 1)][['Date', 'Cases']].copy()
df_Italy = df[(df.Entity=='Italy') & (df.Cases >= 1)][['Date', 'Cases']].copy()
df_France = df[(df.Entity=='France') & (df.Cases >= 1)][['Date', 'Cases']].copy()
df_UK = df[(df.Entity=='United Kingdom') & (df.Cases >= 1)][['Date', 'Cases']].copy()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
plt.rcParams.update({'font.size': 10})
plt.style.use('seaborn-dark')

plt.plot(df_PH.Date, df_PH.Cases, lw=0.5, label='Philippines')
plt.plot(df_Vietnam.Date, df_Vietnam.Cases, lw=0.5, label='Vietnam')
plt.plot(df_SoKor.Date, df_SoKor.Cases, lw=0.5, label='South Korea')
plt.plot(df_Germany.Date, df_Germany.Cases, lw=0.5, label='Germany')


# ax.xaxis.set_minor_locator(mdates.DayLocator(interval=10))
# ax.xaxis.set_major_locator(mdates.DayLocator(interval=10))
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%m-%d'))

plt.title('Confirmed Positive Cases (as of {})'.format(time_stamp))
plt.xlabel('Date')
plt.ylabel('Count')

plt.xticks(rotation=25)
#plt.xlim(pd.to_datetime('2020-03-04'), pd.to_datetime('2020-04-30'))

plt.xlabel('Date')
ax.set_yscale('log')
plt.ylim((10^0, 10**6) )

plt.legend(loc=2)
# Out:
# <img src="data:image/png;base64,..." width="800">
